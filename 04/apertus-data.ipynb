# %%
# !git clone https://github.com/swiss-ai/pretrain-data ./tmp/apertus/pretrain-data

# %% [markdown]
# - [swiss-ai-gutemberg](https://huggingface.co/datasets/swiss-ai/apertus-pretrain-gutenberg)
# - [project gutemberg](https://huggingface.co/datasets/manu/project_gutenberg)

# %%
# !py ./tmp/apertus/pretrain-data/pipelines/gutenberg/create_excerpt.py --num-articles 10 --output-dir ./tmp/apertus/gutenberg-data --seed 42

# %%
import pandas as pd
df = pd.read_json("./tmp/apertus/gutenberg-data/text.jsonl", lines=True)
print(df.head(),df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    10 non-null     object
# dtypes: object(1)
# memory usage: 212.0+ bytes
#                                                 text
# 0   of innocence and virtue can make any one see ...
# 1  \nhave availed, under pressure, to identify hi...
# 2  volver against me--which certain printed words...
# 3   evidently, as a rustic bridge and a weeping w...
# 4   was now standing with his back turned toward ... None
